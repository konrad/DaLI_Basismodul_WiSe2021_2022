# %% [markdown]
# # DaLI Basismodul - Daten auswerten

# %%
Quelle: https://www.umweltbundesamt.de/daten/luft/luftdaten/luftqualitaet/

# %%
import pandas as pd

# %%
url = "https://www.umweltbundesamt.de/api/air_data/v2/measures/csv?date_from=2021-01-01&time_from=1&date_to=2021-10-13&time_to=23&data%5B0%5D%5Bco%5D=1&data%5B0%5D%5Bsc%5D=1&data%5B0%5D%5Bda%5D=2021-10-13&data%5B0%5D%5Bti%5D=14&data%5B0%5D%5Bst%5D=1065&data%5B0%5D%5Bva%5D=null&data%5B1%5D%5Bco%5D=1&data%5B1%5D%5Bsc%5D=1&data%5B1%5D%5Bda%5D=2021-10-13&data%5B1%5D%5Bti%5D=14&data%5B1%5D%5Bst%5D=1177&data%5B1%5D%5Bva%5D=17&lang=de"

# %%
particulates = pd.read_csv(url, sep=";")

# %%
particulates
# Out:
#                                  Bundesland / Messnetz Stationscode  \
# 0                                  Nordrhein-Westfalen      DENW133
# 1                                  Nordrhein-Westfalen      DENW133
# 2                                  Nordrhein-Westfalen      DENW133
# 3                                  Nordrhein-Westfalen      DENW133
# 4                                  Nordrhein-Westfalen      DENW133
# ..                                                 ...          ...
# 282                                Nordrhein-Westfalen      DENW133
# 283                                Nordrhein-Westfalen      DENW133
# 284                                Nordrhein-Westfalen      DENW133
# 285                                Nordrhein-Westfalen      DENW133
# 286  Quelle: Umweltbundesamt, https://www.umweltbun...          NaN
#
#                   Stationsname    Stationsumgebung Art der Station  \
# 0    Hagen Graf-von-Galen-Ring  städtisches Gebiet         Verkehr
# ...

# %%
particulates["Messwert"].hist()
# Out:
# <AxesSubplot:>
